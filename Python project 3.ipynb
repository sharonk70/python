# %%
import random 
import string
import datetime
event_details_dict = {}


class SuperUser:
    
    try:
        global event_details_dict
        


        def __init__(self):
            self.Organizer()
            pass
        
        def Organizer(self):
            print("Here are your options, Event - Organizer \n 1. Create Event\n 2. View Event List\n 3. Update Event\
            \n 4. Delete Event\n 5. View Event Details\n 6. LOGOUT")                        
            i = int(input("Sir, enter your choice\n"))
            while(i not in range(1,7)):
                if i == 7:
                    login()
                    break
                else:
                    print("Sir enter a valid option!\n")
                    i = int(input("Sir Select Correct Option , and make sure its b/w 1 - 6\n"))
                    
            else:     
                if i == 1:
                    self.Create_Event()
                    self.Organizer()
                elif i == 2:
                    self.View_Event
                    self.Organizer()
                    
                elif i == 3:
                    self.Update_Event
                    self.Organizer()
                elif i == 4:
                    self.Delete_Event(input("Please enter the Event-ID to be deleted\n"))
                    self.Organizer()
                elif i == 5:
                    self.View_Event_Details
                    self.Organizer()
                    
        
        def Create_Event(self):
            print(" let's create a Event !\n")
            Event_name = input("Sir,Enter the Event Name to check if Event Name does not exist!\n")
            while Event_name in event_details_dict:
                print("Sorry Sir it seems like the Event Name already exists, would you like to update this instead?\n")
                break
            else:
                event_details_dict[Event_name] = {}
                print("Okay seems like the Event doesn't exist. Enter the details!\n")
                
                event_Id = ''.join([random.choice(string.ascii_letters+ string.digits)
                                    for n in range(6)])  # random event id with 6 char
                
                print("Sir, Your Event Id is:",event_Id)
                event_details_dict[Event_name]["Event Id"] = event_Id
                
                
                
                Event_name = input("Sir,Enter the Event Name\n")
                event_details_dict[Event_name]["Event Name"] = Event_name
    
                Event_Description =input("Sir,Enter the Event Description in 150 Words\n")
                if len(Event_Description) > 150 : 
                    print ("Sir, You have exceeded the word limit")
                else:
                    print(Event_Description)
                while len(Event_Description ) >150 :
                    print("Description is too long.")
                    Event_Description = input("Sir, Please Enter the Event Description in 150 Words : ")
                event_details_dict[Event_name]["Event Descrition"] = Event_Description
                
                Venue = input("Sir,Enter The Event Venue\n")
                event_details_dict[Event_name]["Venue"] = Venue
                
                startDate_time = str(input('Sir,Enter Start Date and time of the Event (yyyy-mm-dd hh:mm):\n'))
                date_format = '%Y-%m-%d'
                try:
                    date_obj = datetime.datetime.strptime(startDate_time, date_format)
                    print(date_obj)
                except ValueError:
                    startDate_time = str(input('Sir,Please Enter Start Date and time of the Event (yyyy-mm-dd hh:mm):\n'))
                event_details_dict[Event_name]["Start Date time"] = startDate_time
                
                endDate_time = str(input('Sir,Enter End Date and time of the Event (yyyy-mm-dd hh:mm):\n'))
                date_format = '%Y-%m-%d'
                try:
                    date_obj = datetime.datetime.strptime(endDate_time, date_format)
                    print(date_obj)
                except ValueError:
                    endDate_time = str(input('Sir,Please Enter End Date and time of the Event (yyyy-mm-dd hh:mm):\n'))
                event_details_dict[Event_name]["End Date time"] = endDate_time
                
                total_seats_available = input("Sir,Total Seats Available!\n")
                while(total_seats_available.isdigit() == False):
                    total_seats_available = input("total_seats_available has to be a number value!\n")
                    
                event_details_dict[Event_name]["Total Seats available"] = total_seats_available
                    
                    
        def View_Event(self):
            check = input("Please Enter The Event Name!\n")
            if check in event_details_dict:
                print("The Details for Event are: ")
                for detail in event_details_dict[check]:
                    if type(event_details_dict[check][detail]) != dict:
                        print('{} : {}'.format(detail, event_details_dict[check][detail]))
                    else:
                        print(detail + ":")
                        for j in event_details_dict[check][detail]:
                            print('{} : {}'.format(j, event_details_dict[check][detail][j]))
            else: 
                print("Sorry, it seems the Member doesn't exist!\n")
                print("Lets go back to the Main Menu!\n\n") 
            
        def Delete_Event(self,Event_name):
            if Event_name in event_details_dict:
                del event_details_dict[Event_name]
            else:
                print("The Event doesn't exist\n")
            print("Lets go back to the Main Menu!\n\n")
                
        def View_Event_Details(self):
            check = input("Sir,Enter The Event Name!\n")
            if check in event_details_dict:
                print("The Details Of The Event are: ")
                for detail in event_details_dict[check]:
                    if type(event_details_dict[check][detail]) != dict:
                        print('{} : {}'.format(detail, event_details_dict[check][detail]))
                    else:
                        print(detail + ":")
                        for j in event_details_dict[check][detail]:
                            print('{} : {}'.format(j, event_details_dict[check][detail][j]))
            else: 
                print("Sorry, it seems the Event-Id doesn't exist!\n")
                print("Lets go back to the Main Menu!\n\n") 
                
        def Update_Event(self):
            check = input("Sir,Please enter the Event Name\n")
            if check in event_details_dict:
                print('Here are the details!')
                label = 1
                for i in event_details_dict[check]:
                    print('{}. {}'.format(label, i))
                    label += 1
                    val = input("Please enter the name of the detail you wish to update\n")
                    while(val not in event_details_dict[check]):
                        print("This detail is not present for the Event \n\n")
                        break
                    else:
                        if val == "Event Name":
                            Event_name = input("Sir,Enter the Event Name\n")
                            print('Congrats! The Event Name is now ', event_details_dict[check]["Event Name"])
                    
                        elif n ==2:
                            Event_Description =input("Sir, Update the Event Description in 150 Words\n")
                            if len(Event_Description) > 150 : 
                                print ("Sir, You have exceeded the word limit")
                            else:
                                print(Event_Description)
                            while len(Event_Description ) >150 :
                                print("Description is too long.")
                                Event_Description = input("Sir, Please Upadte the Event Description in 150 Words : ")
                                print('Congrats! The Event Description is now ', event_details_dict[check]["Event Description"])
                        
                        
                        elif n==3:
                            Venue = input("Sir,Update The Event Venue\n")
                            print('Congrats! The Event Venue is now ', event_details_dict[check]["Event Venue"])
                        
                        elif n==4:
                            startDate_time = str(input('Sir,Enter Start Date and time of the Event (yyyy-mm-dd hh:mm):\n'))
                            date_format = '%Y-%m-%d'
                            try:
                                date_obj = datetime.datetime.strptime(startDate_time, date_format)
                                print(date_obj)
                                
                            except ValueError:
                                startDate_time = str(input('Sir,Please Enter Start Date and time of the Event (yyyy-mm-dd hh:mm):\n'))
                                print('Congrats! The Event Start Date is now ', event_details_dict[check]["Start Date"])
                                
                        elif n==5:
                            endDate_time = str(input('Sir,Enter End Date and time of the Event (yyyy-mm-dd hh:mm):\n'))
                            date_format = '%Y-%m-%d'
                            try:
                                date_obj = datetime.datetime.strptime(endDate_time, date_format)
                                print(date_obj)
                            except ValueError:
                                endDate_time = str(input('Sir,Please Enter End Date and time of the Event (yyyy-mm-dd hh:mm):\n'))
                                print('Congrats! The Event End Date is now ', event_details_dict[check]["End Date"])
                                
                        elif n==6:
                            total_seats_available = input("Sir,Enter Total Seats available\n")
                            print('Congrats! The Event Total Seats Available is now ', event_details_dict[check]["Total Seats Available"])
                            
                        else:
                            member_details_dict[check][val] = input("Please enter the updated value\n")
                            print("Great! The value of {} has been updated to {}\n\n".format(val,member_details_dict[check][val]))
                            
                    print("Lets go back to the Main Menu!\n\n")
    except:
        print("You must have entered an incorrect value!")

# %%
def login():

    print("------Welcome to Let's Meet App------")
    i = int(input("Please enter one of the following!\n1. Event Organizer\n2. Member\n3. Exit\n"))
    while(i not in range(1,3)):
        if i == 3:
            break
        i = int(input("Please enter a valid value!(Either 1 or 2)\n"))
    else:
        if i == 1:
            obj = SuperUser()
        else:
            obj = Member()

login()
# Out:
# ------Welcome to Let's Meet App------
# Please enter one of the following!
# 1. Event Organizer
# 2. Member
# 3. Exit
# 2
# Here are your options, Member
#  1. Create Member
#  2. View Member
#  3. Delete Member
#  4. Update Member
#   5. Logout
# Please enter your choice
# 1
#  Create a Account!
#
# Create a Usernamesharon
# Okay seems like the user doesn't exist. Enter the details!
#
# Create a Password
# sharon
# What is your username?
# sharon
# Password?
# sharon
# Welcome!
# Here are your options, Member
#  1. Create Member
#  2. View Member
#  3. Delete Member
#  4. Update Member
#   5. Logout
# Please enter your choice
# 2
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-6e8880497a41> in <module>
#      13             obj = Member()
#      14
# ---> 15 login()
#
# <ipython-input-17-6e8880497a41> in login()
#      11             obj = SuperUser()
# ...

# %%
print(event_details_dict)
# Out:
# {'sharon': {'Event Id': 'RJAC6e', 'Event Name': 'sharon', 'Event Descrition': 'df', 'Venue': 'd', 'Start Date time': 'def', 'End Date time': 'df', 'Total Seats available': '14'}}

# %%
member_details_dict = {}


class Member:
    try:
        global member_details_dict
        


        def __init__(self):
            self.member()
            pass
        
        
        def member(self):
            print("Here are your options, Member \n 1. Create Member\n 2. View Member\n 3. Delete Member\
            \n 4. Update Member\n  5. Logout")                        
            i = int(input("Please enter your choice\n"))
            while(i not in range(1,5)):
                if i == 9:
                    login()
                    break
                else:
                    print("Please enter a valid option!\n")
                    i = int(input("Please enter your choice, and make sure it's between 1 to 5\n"))
            else:     
                if i == 1:
                    self.create_member()
                    self.member()
                elif i == 2:
                    self.view_member()
                    self.member()
                elif i == 3:
                    self.delete_member(input("Please enter contact number of the Member to be deleted!\n"))
                    self.member()
                elif i == 4:
                    self.update_member()
                    self.member()
                elif i == 5:
                    self.create_regimen()
                    self.member() 
                elif i == 6:
                    self.view_regimen()
                    self.member()
                elif i == 7:
                    self.delete_regimen()
                    self.member()
                elif i == 8:
                    self.update_regimen()
                    self.member()
                    
        def create_member(self):
            print(" Create a Account!\n")
            username = input("Create a Username")
            while username in member_details_dict:
                print("Sorry Sir it seems like the username already exists, would you like to update this instead?\n")
                break
                
            else:
                member_details_dict[username] = {}
                print("Okay seems like the user doesn't exist. Enter the details!\n")
                
                password = input("Create a Password\n")
                member_details_dict[username]["Password"] = password
                
                userInput = input("What is your username?\n")
                if userInput == username:
                    a=input("Password?\n")   
                    if a == password:
                        print("Welcome!")
                    else:
                        print("That is the wrong password.")
                else:
                    print("That is the wrong username.")
                
   
                
    
    except:
        print("You must have entered an incorrect value!")

# %%
 def __init__(self):
        self.username = input("Please Enter Your Username")
        if self.username in member_details_dict:
            print("Welcome, {} to Lets meet app!".format(member_details_dict[self.username]['username']))
            self.member_menu()
        else:
            print("Sorry it seems, you are not a member!\n Please ask the super user to add your details!")
            
            Event_name = input("Sir,Enter the Event Name\n")
            event_details_dict[Event_name]["Event Name"] = Event_name
